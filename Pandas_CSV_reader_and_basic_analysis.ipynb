# %% [markdown]
# # Project 2 - Pandas CSV reader and basic analysis

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv("Instagram_Analytics.csv")
df
# Out:
#          post_id                 upload_date media_type   likes  comments  \
# 0      IG0000001  2024-11-30 09:25:22.954916       Reel   31627      7559
# 1      IG0000002  2025-08-15 09:25:22.954916      Photo   63206      3490
# 2      IG0000003  2025-09-11 09:25:22.954916       Reel   94373      3727
# 3      IG0000004  2025-09-18 09:25:22.954916       Reel  172053      7222
# 4      IG0000005  2025-03-21 09:25:22.954916      Video   99646      2703
# ...          ...                         ...        ...     ...       ...
# 29994  IG0029995  2024-12-18 09:25:22.954916      Video   46046      8354
# 29995  IG0029996  2025-05-05 09:25:22.954916   Carousel   67711      3266
# 29996  IG0029997  2025-05-26 09:25:22.954916      Photo   52326      7328
# 29997  IG0029998  2025-08-02 09:25:22.954916   Carousel  158113      5890
# 29998  IG0029999  2025-04-15 09:25:22.954916      Photo   76368      7115
#
#        shares  saves    reach  impressions  caption_length  hashtags_count  \
# ...

# %%
df.head() # print first 5 rows
# Out:
#      post_id                 upload_date media_type   likes  comments  shares  \
# 0  IG0000001  2024-11-30 09:25:22.954916       Reel   31627      7559    4530
# 1  IG0000002  2025-08-15 09:25:22.954916      Photo   63206      3490    1680
# 2  IG0000003  2025-09-11 09:25:22.954916       Reel   94373      3727    1761
# 3  IG0000004  2025-09-18 09:25:22.954916       Reel  172053      7222    2875
# 4  IG0000005  2025-03-21 09:25:22.954916      Video   99646      2703    4444
#
#    saves    reach  impressions  caption_length  hashtags_count  \
# 0   6393   615036      1007750            1340               3
# 1   6809  1237071      1345900            1351              20
# 2   8367  1127470      1305369             242              24
# 3   9290   764030       897874             446              11
# 4   9746     7004       495406            1905               8
#
#    followers_gained traffic_source  engagement_rate content_category
# ...

# %%
df.tail() # print last 5 rows
# Out:
#          post_id                 upload_date media_type   likes  comments  \
# 29994  IG0029995  2024-12-18 09:25:22.954916      Video   46046      8354
# 29995  IG0029996  2025-05-05 09:25:22.954916   Carousel   67711      3266
# 29996  IG0029997  2025-05-26 09:25:22.954916      Photo   52326      7328
# 29997  IG0029998  2025-08-02 09:25:22.954916   Carousel  158113      5890
# 29998  IG0029999  2025-04-15 09:25:22.954916      Photo   76368      7115
#
#        shares  saves    reach  impressions  caption_length  hashtags_count  \
# 29994    3847  11095   597992       820688            1254              18
# 29995     458  12380  1908094      2218288            1427               4
# 29996    3687   7619  1984066      2447893             713               4
# 29997    2573   6329  1984709      2001092            1341              22
# 29998    4603  11715  1867888      1987738             122              27
#
# ...

# %%
df.dtypes #types in dataset
# Out:
# post_id              object
# upload_date          object
# media_type           object
# likes                 int64
# comments              int64
# shares                int64
# saves                 int64
# reach                 int64
# impressions           int64
# caption_length        int64
# hashtags_count        int64
# followers_gained      int64
# traffic_source       object
# engagement_rate     float64
# content_category     object
# dtype: object

# %%
df.info() # Column names
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29999 entries, 0 to 29998
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   post_id           29999 non-null  object
#  1   upload_date       29999 non-null  object
#  2   media_type        29999 non-null  object
#  3   likes             29999 non-null  int64
#  4   comments          29999 non-null  int64
#  5   shares            29999 non-null  int64
#  6   saves             29999 non-null  int64
#  7   reach             29999 non-null  int64
#  8   impressions       29999 non-null  int64
#  9   caption_length    29999 non-null  int64
#  10  hashtags_count    29999 non-null  int64
#  11  followers_gained  29999 non-null  int64
#  12  traffic_source    29999 non-null  object
#  13  engagement_rate   29999 non-null  float64
#  14  content_category  29999 non-null  object
# dtypes: float64(1), int64(9), object(5)
# memory usage: 3.4+ MB

# %%
#Statistical Values
df.describe() # statistical dashboard
# Out:
#                likes      comments        shares         saves         reach  \
# count   29999.000000  29999.000000  29999.000000  29999.000000  2.999900e+04
# mean    99912.661789   5017.781426   2502.912564   7490.124637  9.965616e+05
# std     57905.967401   2888.404881   1448.320395   4352.546949  5.777906e+05
# min         7.000000      0.000000      0.000000      0.000000  1.650000e+02
# 25%     49755.000000   2530.500000   1246.000000   3690.500000  4.936810e+05
# 50%     99580.000000   5042.000000   2498.000000   7483.000000  9.921810e+05
# 75%    150225.000000   7518.000000   3768.000000  11294.000000  1.494798e+06
# max    200000.000000  10000.000000   5000.000000  15000.000000  1.999865e+06
#
#         impressions  caption_length  hashtags_count  followers_gained  \
# count  2.999900e+04    29999.000000    29999.000000      29999.000000
# mean   1.246669e+06     1103.110904       14.887430        502.152805
# ...

# %%
df.median(numeric_only=True) # central value
# Out:
# likes                 99580.00
# comments               5042.00
# shares                 2498.00
# saves                  7483.00
# reach                992181.00
# impressions         1241026.00
# caption_length         1100.00
# hashtags_count           15.00
# followers_gained        501.00
# engagement_rate           9.19
# dtype: float64

# %%
df.columns # Column inventory
# Out:
# Index(['post_id', 'upload_date', 'media_type', 'likes', 'comments', 'shares',
#        'saves', 'reach', 'impressions', 'caption_length', 'hashtags_count',
#        'followers_gained', 'traffic_source', 'engagement_rate',
#        'content_category'],
#       dtype='object')

# %%
df['comments'].unique()
# Out:
# array([7559, 3490, 3727, ..., 3013, 3507, 3234])

# %%
df['hashtags_count'].unique()
# Out:
# array([ 3, 20, 24, 11,  8, 12, 21, 27, 13, 29, 22,  4, 10,  7, 19,  2,  1,
#         9, 26, 16, 15, 18, 30, 23,  5,  0,  6, 17, 25, 14, 28])

# %%
#filter rows and select colums/ slice rows
df[df['comments'] > 30].head(5)
# Out:
#      post_id                 upload_date media_type   likes  comments  shares  \
# 0  IG0000001  2024-11-30 09:25:22.954916       Reel   31627      7559    4530
# 1  IG0000002  2025-08-15 09:25:22.954916      Photo   63206      3490    1680
# 2  IG0000003  2025-09-11 09:25:22.954916       Reel   94373      3727    1761
# 3  IG0000004  2025-09-18 09:25:22.954916       Reel  172053      7222    2875
# 4  IG0000005  2025-03-21 09:25:22.954916      Video   99646      2703    4444
#
#    saves    reach  impressions  caption_length  hashtags_count  \
# 0   6393   615036      1007750            1340               3
# 1   6809  1237071      1345900            1351              20
# 2   8367  1127470      1305369             242              24
# 3   9290   764030       897874             446              11
# 4   9746     7004       495406            1905               8
#
#    followers_gained traffic_source  engagement_rate content_category
# ...

# %%
df[df['comments'] > 30].tail(5)
# Out:
#          post_id                 upload_date media_type   likes  comments  \
# 29994  IG0029995  2024-12-18 09:25:22.954916      Video   46046      8354
# 29995  IG0029996  2025-05-05 09:25:22.954916   Carousel   67711      3266
# 29996  IG0029997  2025-05-26 09:25:22.954916      Photo   52326      7328
# 29997  IG0029998  2025-08-02 09:25:22.954916   Carousel  158113      5890
# 29998  IG0029999  2025-04-15 09:25:22.954916      Photo   76368      7115
#
#        shares  saves    reach  impressions  caption_length  hashtags_count  \
# 29994    3847  11095   597992       820688            1254              18
# 29995     458  12380  1908094      2218288            1427               4
# 29996    3687   7619  1984066      2447893             713               4
# 29997    2573   6329  1984709      2001092            1341              22
# 29998    4603  11715  1867888      1987738             122              27
#
# ...

# %%
# Slicing Subsets
df.iloc[0 : 10] # 1st 10 rows
# Out:
#      post_id                 upload_date media_type   likes  comments  shares  \
# 0  IG0000001  2024-11-30 09:25:22.954916       Reel   31627      7559    4530
# 1  IG0000002  2025-08-15 09:25:22.954916      Photo   63206      3490    1680
# 2  IG0000003  2025-09-11 09:25:22.954916       Reel   94373      3727    1761
# 3  IG0000004  2025-09-18 09:25:22.954916       Reel  172053      7222    2875
# 4  IG0000005  2025-03-21 09:25:22.954916      Video   99646      2703    4444
# 5  IG0000006  2025-05-06 09:25:22.954916   Carousel   10500      7337    3601
# 6  IG0000007  2025-09-21 09:25:22.954916   Carousel  193906      6326    4384
# 7  IG0000008  2025-01-06 09:25:22.954916   Carousel   27317      3289    2352
# 8  IG0000009  2025-10-13 09:25:22.954916      Photo   90827      6557     570
# 9  IG0000010  2025-03-10 09:25:22.954916      Photo   67067      5988    3223
#
#    saves    reach  impressions  caption_length  hashtags_count  \
# ...

# %%
df.loc[0 : 5, ['saves', 'reach']]
# Out:
#    saves    reach
# 0   6393   615036
# 1   6809  1237071
# 2   8367  1127470
# 3   9290   764030
# 4   9746     7004
# 5   5163   311157

# %%
df.columns
# Out:
# Index(['post_id', 'upload_date', 'media_type', 'likes', 'comments', 'shares',
#        'saves', 'reach', 'impressions', 'caption_length', 'hashtags_count',
#        'followers_gained', 'traffic_source', 'engagement_rate',
#        'content_category'],
#       dtype='object')

# %%
df.loc[df['comments'] > 40, ['shares', 'caption_length']].head(10)
# Out:
#    shares  caption_length
# 0    4530            1340
# 1    1680            1351
# 2    1761             242
# 3    2875             446
# 4    4444            1905
# 5    3601            1448
# 6    4384             904
# 7    2352             400
# 8     570             236
# 9    3223            1219

# %%
df.loc[0 : 25, ['caption_length', 'likes']]
# Out:
#     caption_length   likes
# 0             1340   31627
# 1             1351   63206
# 2              242   94373
# 3              446  172053
# 4             1905   99646
# 5             1448   10500
# 6              904  193906
# 7              400   27317
# 8              236   90827
# 9             1219   67067
# 10            1521  177091
# 11             164   75759
# 12             368   78492
# 13            1205  152517
# 14             539   29834
# 15             739  180946
# 16             166  120368
# 17            1979  180326
# 18            2062  111231
# 19             732   53222
# 20             111  139872
# 21             401  179760
# 22             999  150007
# 23            1377   56044
# 24             371  141510
# 25            1067   77071

# %%
df.loc[0 : 5, ['post_id', 'content_category']]
# Out:
#      post_id content_category
# 0  IG0000001       Technology
# 1  IG0000002          Fitness
# 2  IG0000003           Beauty
# 3  IG0000004            Music
# 4  IG0000005       Technology
# 5  IG0000006      Photography
